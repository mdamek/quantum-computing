# %%
# %matplotlib inline
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from qiskit.visualization import plot_histogram
IBMQ.load_account()
# Out:
# Credentials are already in use. The existing account in the session will be replaced.
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
circ = QuantumCircuit(1)
circ.x(0)
circ.iden(0)
circ.iden(0)
circ.iden(0)
circ.iden(0)
circ.iden(0)
circ.iden(0)
circ.iden(0)
circ.iden(0)
circ.iden(0)
circ.iden(0)
circ.iden(0)
circ.measure_all()
circ.draw()

# %%
provider.backends()
# Out:
# [<IBMQSimulator('ibmq_qasm_simulator') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmqx2') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_16_melbourne') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_vigo') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_ourense') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_london') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_burlington') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_essex') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_armonk') from IBMQ(hub='ibm-q', group='open', project='main')>]

# %%
provider = IBMQ.get_provider(group='open')
backendReal = provider.get_backend('ibmq_london')
backendSim = provider.get_backend('ibmq_qasm_simulator')

# %%
jobReal = execute(circ, backendReal)
resultReal = jobReal.result()
countsReal = resultReal.get_counts()
plot_histogram(countsReal)

# %%
jobSim = execute(circ, backendSim)
resultSim = jobSim.result()
countsSim = resultSim.get_counts()
plot_histogram(countsSim)

# %%
Decoherence was observed. On the simulator, the probability of 1 is 1. On real
the computer is 0.846.
